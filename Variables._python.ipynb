# %% [markdown]
# # variables in python
# 1. variable is memory allocation to value
# 2. examples are name="shivaji",age=36,salary=10000.55
# # key ponits to define variable
# 1.do not start with digit while creating variable
# 2.does not allowed special character in a variable
# 3.do not use keywords as a variable

# %%
name="vikas"
age=26
salary=10000.55
print(name)
print(age)
print(salary)
# Out:
# vikas
# 26
# 10000.55

# %%
1name="vikas"
# Out:
#   Cell In[2], line 1
#     1name="vikas"
#     ^
# SyntaxError: invalid decimal literal

# %%
name=@vikas
# Out:
#   Cell In[3], line 1
#     name=@vikas
#          ^
# SyntaxError: invalid syntax

# %%
for="vikas"
# Out:
#   Cell In[4], line 1
#     for="vikas"
#        ^
# SyntaxError: invalid syntax
