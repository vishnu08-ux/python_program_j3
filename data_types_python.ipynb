# %% [raw]
# # data types in python
# 1.different vatype of values assinged tob variables
# 2.basically 3 data types in pythont
# 3.int(intger)-numerical values like1,2,3,4.......,n
# 4.str(string)- character examples "abcd","grjk","qwerty"
# 5.float(decimals)-numerical with decimals-10.25,100.25,125.35

# %%
name="vikas"
age=25ZZ
salary=100023.25
data="123"
print(name)
print(age)
print(salary)
print(data)
print(type(name))
print(type(age))
print(type(salary))
print(type(data))
# Out:
# vikas
# 25
# 100023.25
# 123
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
# concatenations
a=100
b=200
print(a+b)
# Out:
# 300

# %%
n1="python"
n2="programming"
print(n1+n2)
# Out:
# pythonprogramming

# %%
a=100
b="300"
print(a+(int)(b))
# Out:
# 400
